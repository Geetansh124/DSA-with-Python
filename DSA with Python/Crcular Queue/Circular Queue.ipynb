# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.items = [None]*size
        self.front = self.rear = -1

    def insert(self, value):
        if( (self.rear + 1) % self.size == self.front):
            print("Queue is full")
        elif self.front == -1:
            self.front = self.rear = 0
            self.items[self.rear] = value
        else:
            self.rear = (self.rear + 1) % self.size
            self.items[self.rear] = value

    def dequeue(self):
        if (self.front == -1):
            print("Queue is empty")
        elif self.front == self.rear:
            print(self.items[self.front])
            self.front = self.rear = -1
        else:
            print(self.items[self.front])
            self.front = (self.front + 1)%self.size


cq = CircularQueue(5)
cq.insert(10)
cq.insert(20)
cq.insert(30)
cq.insert(40)
cq.insert(50)
cq.dequeue()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 28
#      24             print(self.items[self.front])
#      25             self.front = (self.front + 1)%self.size
# ---> 28 cq = CircularQueue(5)
#      29 cq.insert(10)
#      30 cq.insert(20)
#
# Cell In[8], line 5, in CircularQueue.__init__(self, size)
#       3 self.size = size
#       4 self.items = [None]*size
# ----> 5 size.front = self.rear = -1
#
# AttributeError: 'int' object has no attribute 'front' and no __dict__ for setting new attributes
