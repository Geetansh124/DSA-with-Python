# %% [markdown]
# ***Fractional Knapsack _ Greedy Algorithm***

# %%
def Fractional_knapsack(items_wt, price, capacity):
    n = len(items_wt)
    
    items = [(price[i], items_wt[i], price[i]/items_wt[i]) for i in range(n)]
    
    for i in range(n):
        for j in range(i+1, n):
            if(items[i][2] < items[j][2]):
                items[i], items[j], = items[j], items[i]
                
        profit = 0.0
        
        for price, items_wt, perKgPrice in items:
            if(capacity >= items_wt):
                capacity = capacity - items_wt
                profit = profit + price
            else:
                profit = profit + perKgPrice
                
        print("Total Profit = ", profit)    
price = [24,21,12,10]
items_wt = [7,4,3,5]
capacity = 20
Fractional_knapsack(items_wt, price, capacity)
# Out:
# Total Profit =  67.0
# Total Profit =  14.678571428571429
# Total Profit =  14.678571428571429
# Total Profit =  14.678571428571429
